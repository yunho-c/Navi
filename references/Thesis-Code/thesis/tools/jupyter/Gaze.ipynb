# %%
import json
import os

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import streamlit as st
import tikzplotlib
from scipy import stats

from thesis.tools.st_utils import file_select
from thesis.tools.cli.utilities import load_gaze_data
# Out:
# /Users/Anton/anaconda3/envs/iaml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/Anton/anaconda3/envs/iaml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/Anton/anaconda3/envs/iaml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/Anton/anaconda3/envs/iaml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/Anton/anaconda3/envs/iaml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/Anton/anaconda3/envs/iaml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2020-11-12 18:30:40.822 WARNING tensorflow: From /Users/Anton/Documents/git/thesis/Thesis-Code/thesis/deepeye/deepeye.py:39: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d instead.
# 2020-11-12 18:30:40.838 WARNING tensorflow: From /Users/Anton/anaconda3/envs/iaml/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2020-11-12 18:30:40.853 WARNING tensorflow: From /Users/Anton/Documents/git/thesis/Thesis-Code/thesis/deepeye/deepeye.py:42: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.batch_normalization instead.
# Deep_eye
# conv_unit_1
# stride_unit_1
# 2020-11-12 18:30:41.144 WARNING tensorflow: From /Users/Anton/Documents/git/thesis/Thesis-Code/thesis/deepeye/deepeye.py:74: average_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.average_pooling2d instead.
# Last_conv1x1_1
# conv_unit_2
# stride_unit_2
# Last_conv1x1_2
# atrous_unit_1
# 2020-11-12 18:30:42.154 WARNING tensorflow: From /Users/Anton/Documents/git/thesis/Thesis-Code/thesis/deepeye/deepeye.py:109: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.max_pooling2d instead.
# conv_unit_3
# atrous_unit_2
# conv_unit_4
# Last_conv1x1_3
# 2020-11-12 18:30:43.548 WARNING tensorflow: From /Users/Anton/anaconda3/envs/iaml/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2020-11-12 18:30:43.550 INFO    tensorflow: Restoring parameters from /Users/Anton/Documents/git/thesis/Thesis-Code/thesis/deepeye/models/default.ckpt
# Model restored.

# %%
plt.rc('font', family='serif')
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')
sns.set_context('paper')

# %%
from tqdm import tqdm
from numba import njit, prange, jit

from thesis.optim.metrics import *
from thesis.optim import filters

# %%
gaze_thresholds = ''

# %%
file_path = '../../../results/recognition/rc1_gaze_at_1x.json'
with open(file_path) as file:
    data = json.load(file)

# %%
base_path = '../../../results/recognition/'
file_names = ('rc1_gaze_at_1x.json', 'rc1_gaze_at_2x.json', 'rc1_gaze_at_5x.json')
files = []
for fpath in file_names: 
    print('starting')
    with open(os.path.join(base_path, fpath)) as file:
        files.append(json.load(file))
# Out:
# starting
# starting
# starting

# %%
scales = ('1x', '2x', '5x')
files = {s: f for s, f in zip(scales, files)}

# %%
config = data['config']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a23b748151fb> in <module>
# ----> 1 config = data['config']
#
# NameError: name 'data' is not defined

# %%
#gaze_sets = ('far_home', 'mor_home', 'anton', 'maja', 'jakob')
gaze_sets = ('anton', 'maja')
base_path = '/Users/Anton/MEGA/Data/thesis/gaze'
gaze_paths = [os.path.join(base_path, g) for g in gaze_sets]
datasets = load_gaze_data(gaze_paths)
# Out:
# 60.0
# 60.0

# %%
def test_filter(f_func, args):
    logger = Logger()
    me = GazeAccuracy()

    for dset in datasets:
        for sample in tqdm(dset.test_samples):
            filtered = f_func(sample.image, **args)
            me.log(logger, dset.model, sample, filtered)
    
    return logger

# %%
res = []
for k, v in config['filters'].items():
    res.append(test_filter(getattr(filters, k), v))
# Out:
# 100%|██████████| 50/50 [00:36<00:00,  1.36it/s]
# 100%|██████████| 50/50 [00:35<00:00,  1.40it/s]
# 100%|██████████| 50/50 [00:33<00:00,  1.50it/s]
# 100%|██████████| 50/50 [00:31<00:00,  1.59it/s]
# 100%|██████████| 50/50 [00:36<00:00,  1.36it/s]
# 100%|██████████| 50/50 [00:31<00:00,  1.58it/s]
# 100%|██████████| 50/50 [00:34<00:00,  1.45it/s]
# 100%|██████████| 50/50 [00:35<00:00,  1.39it/s]
# 100%|██████████| 50/50 [00:48<00:00,  1.04it/s]
# 100%|██████████| 50/50 [00:41<00:00,  1.20it/s]
# 100%|██████████| 50/50 [00:37<00:00,  1.33it/s]
# 100%|██████████| 50/50 [00:36<00:00,  1.39it/s]
# 100%|██████████| 50/50 [00:36<00:00,  1.37it/s]
# 100%|██████████| 50/50 [00:40<00:00,  1.22it/s]
# 100%|██████████| 50/50 [00:33<00:00,  1.47it/s]
# 100%|██████████| 50/50 [00:38<00:00,  1.29it/s]

# %%
res[1].means()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-33ac708cef9a> in <module>
# ----> 1 res[1].means()
#
# NameError: name 'res' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
@njit
def metrics(intra, inter, t):
    tp = (intra <= t).sum()
    tn = (inter > t).sum()
    fp = (inter <= t).sum()
    fn = (intra > t).sum()
    return {
        'threshold': t,
        'tp': tp,
        'tn': tn,
        'fp': fp,
        'fn': fn,
        'far': fp/(fp+tn),
        'frr': fn/(fn+tp)
    }

@njit
def find_gt(sorted_array, value, start=0):
    i = start
    while i < len(sorted_array):
        if sorted_array[i] >= value:
            break
        i += 1
    return i

def line(intra, inter):
    res = []
    
    sorted_intra = np.sort(intra)
    sorted_inter = np.sort(inter)
    n_intra = len(intra)
    n_inter = len(inter)
    intra_idx = 0
    inter_idx = 0
    for i in prange(100):
        x = i/100
        
        intra_idx = find_gt(sorted_intra, x, intra_idx)
        inter_idx = find_gt(sorted_inter, x, inter_idx)
        
        tp = intra_idx
        tn = n_inter - inter_idx
        fp = inter_idx
        fn = n_intra - intra_idx
        
        m = {
            'threshold': x,
            'tp': tp,
            'tn': tn,
            'fp': fp,
            'fn': fn,
            'far': fp/(fp+tn),
            'frr': fn/(fn+tp),
        }
        res.append(m)
    return res

# %%
res = {}
for s, data in files.items():
    res[s] = []
    for spec in tqdm(data['results'].keys()):
        intra = np.array(data['results'][spec]['intra_distance'])
        inter = np.array(data['results'][spec]['inter_distance'])
        ls = line(intra, inter)
        ls = list(map(dict, ls))
        for l in ls:
            l['name'] = spec
            #l['scale'] = 
        res[s].extend(ls)
# Out:
# 100%|██████████| 9/9 [00:09<00:00,  1.11s/it]
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# 100%|██████████| 9/9 [00:09<00:00,  1.05s/it]

# %%
dfs= []
for s, d in res.items():
    df = pd.DataFrame.from_records(d)
    df['scale'] = s
    dfs.append(df)
df = pd.concat(dfs)

# %%
filter_name_map = {
    'bilateral_filter': 'Bilateral filter',
    'gaussian_filter': 'Gaussian filter',
    'mean_filter': 'Mean filter',
    'median_filter': 'Median filter',
    'non_local_means': 'Non-local means',
    'uniform_noise': 'Uniform noise',
    'gaussian_noise': 'Gaussian noise',
    'cauchy_noise': 'Cauchy noise',
    'laplacian_noise': 'Laplacian noise',
    'snow': 'Snow noise',
    'salt_and_pepper': 'Salt-and-pepper noise',
    'baseline': 'Baseline'
}

# %%
df['precision'] = df['tp']/(df['tp']+df['fp'])
df['recall'] = df['tp']/(df['tp']+df['fn'])
df['f1'] = (df['precision']*df['recall'])/(df['precision'] + df['recall'])
df['accuracy'] = (df['tp']+df['tn'])/(df['tp']+df['tn']+df['fp']+df['fn'])
df['Filter'] = df['name'].apply(filter_name_map.get)

# %%
from thesis import colorblind

# %%
col = colorblind.qualitative_colors(3)
sns.set_palette(col)
grid = sns.FacetGrid(df, col='Filter', hue='scale', height=2, col_wrap=4)
grid.map(sns.lineplot, 'far', 'frr').set(xscale='log', yscale='log')
grid.add_legend()
grid.savefig('out/iris-comp.pdf')

# %%
tikzplotlib.save('out/test.tex', figure=grid.fig, standalone=True)

# %%
fig, ax = plt.subplots(figsize=(10, 8))

sns.lineplot(x='recall', y='precision', hue='name', data=df, ax=ax, groupby='scale')
#ax.set_xscale('log')
#ax.set_yscale('log')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-7422673fad10> in <module>
#       1 fig, ax = plt.subplots(figsize=(10, 8))
#       2
# ----> 3 sns.lineplot(x='recall', y='precision', hue='name', data=df, ax=ax, groupby='scale')
#       4 #ax.set_xscale('log')
#       5 #ax.set_yscale('log')
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     694     p._attach(ax)
#     695
# --> 696     p.plot(ax, kwargs)
#     697     return ax
#     698
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     434         # function will advance the axes property cycle.
#     435
# --> 436         scout, = ax.plot([], [], **kws)
#     437
#     438         orig_color = kws.pop("color", scout.get_color())
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     362                 "non-matching shapes is deprecated.")
#     363         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
# --> 364                 for j in range(max(ncx, ncy))]
#     365
#     366
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#     362                 "non-matching shapes is deprecated.")
#     363         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
# --> 364                 for j in range(max(ncx, ncy))]
#     365
#     366
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     253         default_dict = self._getdefaults(set(), kw)
#     254         self._setdefaults(default_dict, kw)
# --> 255         seg = mlines.Line2D(x, y, **kw)
#     256         return seg
#     257
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     398         # update kwargs before updating data to give the caller a
#     399         # chance to init axes (and hence unit support)
# --> 400         self.update(kwargs)
#     401         self.pickradius = pickradius
#     402         self.ind_offset = 0
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~/anaconda3/envs/iaml/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1000                 if not callable(func):
#    1001                     raise AttributeError('{!r} object has no property {!r}'
# -> 1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#    1004
#
# AttributeError: 'Line2D' object has no property 'groupby'

# %%
fig, ax = plt.subplots(figsize=(10, 8))

sns.lineplot(x='threshold', y='far', hue='name', data=df, ax=ax)
ax.set_yscale('log')
ax.vlines(0.3, 0, 1)

# %%
pv = df.pivot(columns='name', index='threshold')

# %%
ts = np.round(np.arange(0.3, 0.4, 0.01), decimals=2)
pv.loc[ts]['far']
# Out:
# name           baseline  bilateral_filter  cauchy_noise  gaussian_filter  \
# threshold
# 0.30       0.000000e+00          0.000104  0.000000e+00         0.000013
# 0.31       1.440130e-07          0.001010  0.000000e+00         0.000273
# 0.32       8.640779e-07          0.004977  0.000000e+00         0.002064
# 0.33       1.108900e-05          0.016831  0.000000e+00         0.006100
# 0.34       8.424760e-05          0.043774  0.000000e+00         0.016399
# 0.35       4.281506e-04          0.097756  0.000000e+00         0.040132
# 0.36       1.777984e-03          0.190801  0.000000e+00         0.086215
# 0.37       6.711581e-03          0.323222  0.000000e+00         0.172391
# 0.38       2.220176e-02          0.481142  8.640779e-07         0.307945
# 0.39       6.391081e-02          0.643913  6.048546e-06         0.477297
# 0.40       1.551836e-01          0.786377  8.021524e-05         0.654808
#
# name       gaussian_noise  mean_filter  median_filter  non_local_means  \
# threshold
# 0.30         0.000000e+00     0.000003       0.000076         0.000167
# 0.31         0.000000e+00     0.000136       0.000590         0.000964
# 0.32         0.000000e+00     0.001621       0.002644         0.003859
# 0.33         0.000000e+00     0.008185       0.009191         0.012560
# 0.34         0.000000e+00     0.024863       0.028080         0.034249
# 0.35         0.000000e+00     0.059326       0.072038         0.080628
# 0.36         0.000000e+00     0.126654       0.155301         0.163593
# 0.37         0.000000e+00     0.237574       0.288211         0.289083
# 0.38         1.440130e-07     0.386646       0.462246         0.447391
# 0.39         3.168286e-06     0.552484       0.648200         0.616420
# 0.40         6.221361e-05     0.713693       0.808843         0.768247
#
# name       uniform_noise
# threshold
# 0.30            0.000000
# 0.31            0.000000
# 0.32            0.000000
# 0.33            0.000000
# 0.34            0.000000
# 0.35            0.000000
# 0.36            0.000000
# 0.37            0.000000
# 0.38            0.000001
# 0.39            0.000019
# 0.40            0.000207

# %%
sns.set_theme('paper')
sns.set_style('whitegrid')

# %%
fig, ax = plt.subplots()

sns.lineplot(x='far', y='frr', hue='name', data=df, ax=ax, estimator=None)
sns.scatterplot(x='far', y='frr', hue='name', data=df[df['threshold'] == 0.33], ax=ax, marker='X', legend=False)

ax.set_xscale('log')
ax.set_yscale('log')

fig.savefig('out/filters.pdf')
