# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from thesis.tracking.features import pupil_detector
from thesis.data import SegmentationDataset

# %%
# image = cv.imread('/home/anton/data/eyedata/iris/images/casia4i/002/L/S1002L07.jpg', cv.IMREAD_GRAYSCALE)
image = cv.imread('/Users/Anton/Desktop/data/iris/images/casia4i/001/L/S1001L01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(image)

# %%
pupil_detector(image)
# Out:
# [114.92443084716797,
#  155.02484130859375,
#  113.59955596923828,
#  108.66943359375,
#  75.21255493164062]

# %%
from thesis.optim.objective_terms import bilateral_filter
from thesis.optim.objective_terms import gradient_entropy
from thesis.optim.filters import gfilter

img2 = bilateral_filter(image, 21, 255, 20)
plt.imshow(img2)

# %%
dset = SegmentationDataset.from_path('/Users/Anton/Desktop/data/iris/casia4i.json')

# %%
plt.imshow(dset.samples[0].image.image)

# %%
plt.imshow(dset.samples[0].image.mask)

# %%
img = dset.samples[0].image
gradient_entropy(img.image, img.mask)

# %%
img2 = bilateral_filter(img.image, 21, 255, 20)
# img2 = gfilter(img.image, 45, 255)
print(gradient_entropy(img2, img.mask))
plt.imshow(img2, cmap='gray')

# %%
from thesis.data import GazeDataset

# %%
dset = GazeDataset.from_path('/Users/Anton/Desktop/data/caps/cap01/')

# %%
dset.model.predict(dset.test_samples[0].image)

# %%
plt.imshow(dset.samples[0].image.image)

# %%
plt.imshow(dset.samples[0].image.mask)

# %%
img = dset.samples[0].image
gradient_entropy(img.image, img.mask)
# Out:
# 11.184003542484286

# %%
img2 = bilateral_filter(img.image, 21, 255, 20)
# img2 = gfilter(img.image, 45, 255)
print(gradient_entropy(img2, img.mask))
plt.imshow(img2, cmap='gray')
# Out:
# 7.903298323083505

# %%
from thesis.data import GazeDataset

# %%
dset = GazeDataset.from_path('/Users/Anton/Desktop/data/caps/cap01/')

# %%
dset.model.predict(dset.test_samples[0].image)
# Out:
# array([[0.42738672, 0.3278949 ]])
